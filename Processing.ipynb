# %%
import pandas as pd
import re
from datetime import datetime

# %%
input_list = ['HMV_2025 Hospital_Daily Tracking - Copy 11.06.2025.xlsx',
 '2025_HMDL_Hospital_Daily Tracking_Template.xlsx',
 'Giáp_Hospital tracking TMTDM.xlsx',
 '2025 hmsg daily tracking sales.xlsx',
 'HMGPXL_Daily Tracking.xlsx',
 'HMTD_Daily Tracking_New link.xlsx',
 'Hospital_Daily Tracking.xlsx',
 'HMCL - Hospital_Daily Tracking_Template 10.04.25.xlsx',
 'HMBP - Hospital_Daily Tracking_Template 10.04.25.xlsx',
 'HMBD - Hospital_Daily Tracking_Template 10.04.25.xlsx',
 'HMMH - Hospital_Daily Tracking_Template 10.04.25.xlsx',
 '2025_TMBD_Hospital_Daily Tracking.xlsx',
 'Hospital_Daily Tracking_Template Region2 (Ver Apr 14).xlsx',
 '2025_HMDNG_Hospital_Daily Tracking.xlsx',
 'HPEC_Daily Tracking.xlsx',
 'HMDNI - Hospital_Daily Tracking_Template 10.04.25.xlsx']
output_list = ['HMV_2025 Hospital_Daily Tracking - Copy 11.06.2025_python.xlsx',
 '2025_HMDL_Hospital_Daily Tracking_Template_python.xlsx',
 'Giáp_Hospital tracking TMTDM_python.xlsx',
 '2025 hmsg daily tracking sales_python.xlsx',
 'HMGPXL_Daily Tracking_python.xlsx',
 'HMTD_Daily Tracking_New link_python.xlsx',
 'HPH_Hospital_Daily Tracking_python.xlsx',
 'HMCL - Hospital_Daily Tracking_Template 10.04.25_python.xlsx',
 'HMBP - Hospital_Daily Tracking_Template 10.04.25_python.xlsx',
 'HMBD - Hospital_Daily Tracking_Template 10.04.25_python.xlsx',
 'HMMH - Hospital_Daily Tracking_Template 10.04.25_python.xlsx',
 '2025_TMBD_Hospital_Daily Tracking_python.xlsx',
 'Hospital_Daily Tracking_Template Region2 (Ver Apr 14)_python.xlsx',
 '2025_HMDNG_Hospital_Daily Tracking_python.xlsx',
 'HPEC_Daily Tracking_python.xlsx',
 'HMDNI - Hospital_Daily Tracking_Template 10.04.25_python.xlsx']

# %%
input_list = ['HMBP - Hospital_Daily Tracking_Template 10.04.25.xlsx']
output_list = ['HMBP - Hospital_Daily Tracking_Template 10.04.25_python.xlsx']

# %%
input_list = ['2025 hmsg daily tracking sales.xlsx',
 'HMGPXL_Daily Tracking.xlsx',
 'HMTD_Daily Tracking_New link.xlsx',
 'Hospital_Daily Tracking.xlsx',
 'HPEC_Daily Tracking.xlsx']
output_list = ['2025 hmsg daily tracking sales_python.xlsx',
 'HMGPXL_Daily Tracking_python.xlsx',
 'HMTD_Daily Tracking_New link_python.xlsx',
 'HPH_Hospital_Daily Tracking_python.xlsx',
 'HPEC_Daily Tracking_python.xlsx']

# %%
input_list = ['HMDNI - Hospital_Daily Tracking_Template 10.04.25.xlsx',
              'HMBP - Hospital_Daily Tracking_Template 10.04.25.xlsx']
output_list = ['HMDNI - Hospital_Daily Tracking_Template 10.04.25_python.xlsx',
               'HMBP - Hospital_Daily Tracking_Template 10.04.25_python.xlsx']

# %%
input_list = ['HMDNI - Hospital_Daily Tracking_Template 10.04.25.xlsx']
output_list = ['HMDNI - Hospital_Daily Tracking_Template 10.04.25_python.xlsx']

# %%
input_list = ['HMV_2025 Hospital_Daily Tracking - Copy 11.06.2025.xlsx',
 '2025_HMDL_Hospital_Daily Tracking_Template.xlsx',
 'Giáp_Hospital tracking TMTDM.xlsx',
 '2025_TMBD_Hospital_Daily Tracking.xlsx',
 'Hospital_Daily Tracking_Template Region2 (Ver Apr 14).xlsx',
 '2025_HMDNG_Hospital_Daily Tracking.xlsx']
output_list = ['HMV_2025 Hospital_Daily Tracking - Copy 11.06.2025_python.xlsx',
 '2025_HMDL_Hospital_Daily Tracking_Template_python.xlsx',
 'Giáp_Hospital tracking TMTDM_python.xlsx',
 '2025_TMBD_Hospital_Daily Tracking_python.xlsx',
 'Hospital_Daily Tracking_Template Region2 (Ver Apr 14)_python.xlsx',
 '2025_HMDNG_Hospital_Daily Tracking_python.xlsx']

# %%
input_list = ['HMCL - Hospital_Daily Tracking_Template 10.04.25.xlsx',
 'HMBP - Hospital_Daily Tracking_Template 10.04.25.xlsx',
 'HMBD - Hospital_Daily Tracking_Template 10.04.25.xlsx',
 'HMMH - Hospital_Daily Tracking_Template 10.04.25.xlsx',
 'HMDNI - Hospital_Daily Tracking_Template 10.04.25.xlsx']
output_list = ['HMCL - Hospital_Daily Tracking_Template 10.04.25_python.xlsx',
 'HMBP - Hospital_Daily Tracking_Template 10.04.25_python.xlsx',
 'HMBD - Hospital_Daily Tracking_Template 10.04.25_python.xlsx',
 'HMMH - Hospital_Daily Tracking_Template 10.04.25_python.xlsx',
 'HMDNI - Hospital_Daily Tracking_Template 10.04.25_python.xlsx']

# %%
'''Hàm xóa khoảng trắng thừa'''
def remove_space(text):
    if isinstance(text, str):
        '''Loại bỏ khoảng trắng thừa và các kí tự đặc biệt ở đầu và cuối'''
        text = text.strip(" ,.x\xa0")
        '''Loại bỏ khoảng trắng thừa ở giữa'''
        text = re.sub(r'\s+', ' ', text)
        '''Loại bỏ dấu -, nhưng phải tách riêng ra câu lệnh khác vì để chung strip sẽ bị mất số âm'''
        if text == '-':
            text = text.strip("-")
        return text
    return text

# %%
def remove_dot_between_digits(x):
    return re.sub(r'(?<=\d)\.(?=\d)', '', str(x))

# %%
def convert_datetime(date, f = "%d/%m/%Y"):
    try:
        date = datetime.strptime(date, f)
        return date.strftime("%Y-%m-%d %H:%M:%S")
    except ValueError:
        return date

# %%
def convert_datetime_r3(date, f = "%d/%m/%Y"):
    try:
        date = datetime.strptime(date, f)
        return date.strftime("%Y-%m-%d %H:%M:%S")
    except:
        pass

    try:
        dt = datetime.strptime(date, "%Y-%d-%m %H:%M:%S")
        return dt.strftime("%Y-%m-%d %H:%M:%S")
    except:
        pass

# %%
def HMDNG_ref_partner(name):
    if name == str.upper('Pkham Thiện Nhân'):
        name = str.upper('Thiện Nhân Clinic')
    if name == str.upper('TT 115 Đà Nẵng'):
        name = str.upper('TT115 Đà Nẵng')
    if name == str.upper('Trương Bình Phương Wellbe') or name == str.upper('Wellbe/ Trương Bình Phương') or name == str.upper('Trương Bình Phương/ Wellbe'):
        name = str.upper('Trương Bình Phương')
    if name == str.upper('Trần Thành Nghĩa _ tiếng nga'):
        name = str.upper('Trần Thành Nghĩa')
    if name == str.upper('PK Adam&Eva'):
        name = str.upper('PK Adam & Eva')
    return name
def HMDNG_ref_daily(name):
    if name == str.upper('Thiện Nhân'):
        name = str.upper('Thiện Nhân Clinic')
    if name == str.upper('TT 115 Đà Nẵng'):
        name = str.upper('TT115 Đà Nẵng')
    if name == str.upper('Trương Bình Phương Wellbe') or name == str.upper('Wellbe/ Trương Bình Phương') or name == str.upper('Trương Bình Phương/ Wellbe'):
        name = str.upper('Trương Bình Phương')
    if name == str.upper('PK Adam&Eva'):
        name = str.upper('PK Adam & Eva')
    return name

# %%
def ITO_ref_partner(name):
    if name.startswith("BS."):
         name = name.replace("BS.", "BS")
    return name
def ITO_ref_daily(name):
    if name == str.upper('BS Mai Xuân Tài'):
        name = str.upper('MG Mai Xuân Tài')
    #if name == str.upper('MG Võ Quốc Hùng'): #Không cần nữa vì file ITO đã chỉnh
    #    name = str.upper('BS Võ Quốc Hùng')
    if name.startswith("BS."):
         name = name.replace("BS.", "BS")
    return name

# %%
def HMMH_ref_daily(name):
    if name == str.upper('CÔNG TY CP ĐẦU TƯ BCARE'):
        name = 'BCARE'
    return name
def HMMH_ref_partner(name):
    if name == str.upper('CÔNG TY CP ĐẦU TƯ BCARE'):
        name = 'BCARE'
    return name

# %%
def HMBD_ref_partner(name):
    if name.startswith("BS "):
        name = name.replace("BS ", "")
    if name == 'HỒ ANH HÙNG VỸ':
        name = 'HỒ ANH HÙNG VĨ'
    return name
def HMBD_ref_daily(name):
    if name.startswith("BS "):
         name = name.replace("BS ", "")
    if name == 'THUẬN MỸ TDM':
         name = 'TM TDM'
    if name == 'B-CARE':
         name = 'BCARE'
    if name == 'HỒ ANH HÙNG VỸ':
        name = 'HỒ ANH HÙNG VĨ'
    return name

# %%
def HMDNI_ref_partner(name):
    if name.startswith("BS. "):
        name = name.replace("BS. ", "BS ")
    if name.startswith("BS."):
        name = name.replace("BS.", "BS ")
    if name.startswith("CTV. "):
        name = name.replace("CTV. ", "CTV ")
    if name.startswith("CTV."):
        name = name.replace("CTV.", "CTV ")
    if name.startswith("PK. "):
        name = name.replace("PK. ", "PK ")
    if name.startswith("PK."):
        name = name.replace("PK.", "PK ")
    if name == 'CTV PHẠM THI KIM PHƯỢNG':
        name = 'CTV PHẠM THỊ KIM PHƯỢNG'
    if name == 'ĐẶNG ĐẠI HÙNG':
        name = 'CTV ĐẶNG ĐẠI HÙNG'
    if name == 'NGUYỄN VĂN TÙNG':
        name = 'CTV NGUYỄN VĂN TÙNG'
    return name
def HMDNI_ref_daily(name):
    if name.startswith("BS. "):
        name = name.replace("BS. ", "BS ")
    if name.startswith("BS."):
        name = name.replace("BS.", "BS ")
    if name.startswith("CTV. "):
        name = name.replace("CTV. ", "CTV ")
    if name.startswith("CTV."):
        name = name.replace("CTV.", "CTV ")
    if name.startswith("PK. "):
        name = name.replace("PK. ", "PK ")
    if name.startswith("PK."):
        name = name.replace("PK.", "PK ")
    if name == 'HÁN VĂN NAM':
        name = 'CTV HÁN VĂN NAM'
    return name

# %%
#def HMBP_ref_partner(name):
def HMBP_ref_daily(name):
    if name == 'BS TRÁNG (PK TÂM PHÚC)':
        name = 'ĐÀO VĂN TRÁNG (PK TÂM PHÚC)'
    if name == 'CÔNG TY TNHH NEW APPARER FAR EASTERN VIỆT NAM':
        name = 'CÔNG TY TNHH NEW APPAREL FAR EASTERN VIỆT NAM'
    if name == 'ĐOÀN VĂN HOÀ':
        name = 'ĐOÀN VĂN HÒA'
    if name == 'NGUYỄN CAO CƯỜNG ADRONG':
        name = 'NGUYỄN CAO CƯỜNG ADRƠNG'
    return name

# %%
#def HMCL_ref_partner(name):
def HMCL_ref_daily(name):
    if 'BCARE' in name:
        name = 'BCARE'
    return name

# %%
#def HPH_ref_partner(name):
def HPH_ref_daily(name):
    if name == 'BOOKING CARE' or name == 'BOOKINGCARE':
        name = 'CÔNG TY CỔ PHẦN CÔNG NGHỆ BOOKINGCARE'
    if name == 'HOAN MY GO VAP CLINIC':
        name = 'PHÒNG KHÁM HOÀN MỸ GÒ VẤP'
    if name == 'NGUYẾN TRƯỜNG MẠNH':
        name = 'NGUYỄN TRƯỜNG MẠNH'
    return name

# %%
def TMTDM_ref_partner(name):
    if name == 'HOANG MẠNH THẮNG':
        name = 'HOÀNG MẠNH THẮNG'
    return name
#def TMTDM_ref_daily(name):

# %%
def HMTD_ref_partner(name):
    if name == 'PHÒNG KHÁM TRẦM HƯƠNG':
        name = 'TRẦM HƯƠNG HEALTHCARE'
    return name
def HMTD_ref_daily(name):
    if name == 'BV HẠNH PHÚC':
        name = 'BỆNH VIỆN HẠNH PHÚC'
    if name == 'PK Y SÀI GÒN':
        name = 'PHÒNG KHÁM Y SÀI GÒN'
    return name

# %%
def HMSG_ref_partner(name):
    if name.startswith("HM"):
        name = name.replace("HM", "HOÀN MỸ")
    return name
def HMSG_ref_daily(name):
    if name.startswith("HM"):
        name = name.replace("HM", "HOÀN MỸ")
    return name

# %%
def HMV_ref_partner(name):
    if name == 'CÔNG TY CỔ PHẦN ĐẦU TƯ BCARE':
        name = 'BCARE'
    return name
def HMV_ref_daily(name):
    if name == 'CÔNG TY CỔ PHẦN ĐẦU TƯ BCARE':
        name = 'BCARE'
    return name

# %%
link = 'C:/Users/lpn001-ho/OneDrive - Hoan My Medical Corporation/Daily Tracking/100126/'

# %%
exp1_list = [link + 'HMMH - Hospital_Daily Tracking_Template 10.04.25.xlsx',
link + 'HMBD - Hospital_Daily Tracking_Template 10.04.25.xlsx',
link + 'HMBP - Hospital_Daily Tracking_Template 10.04.25.xlsx',
link + 'HMCL - Hospital_Daily Tracking_Template 10.04.25.xlsx',
link + 'HMDNI - Hospital_Daily Tracking_Template 10.04.25.xlsx']

# %%
def processing(file_name, output):
    if file_name in exp1_list:
        df_ref = pd.read_excel(file_name, sheet_name = '1.1 Referral_Daily Input ', dtype = str, skiprows=[0])
        df_partner = pd.read_excel(file_name, sheet_name = '1.2 Referral_Partner List',  dtype = str)
        df_chc = pd.read_excel(file_name, sheet_name = '2. CHC_Daily Input', dtype = str, skiprows=[0])
        df_b2c = pd.read_excel(file_name, sheet_name = '3. Daily_B2C Input', dtype = str, skiprows=[0])
    elif file_name == link + '2025_TMBD_Hospital_Daily Tracking.xlsx' or file_name == link + 'HMV_2025 Hospital_Daily Tracking - Copy 11.06.2025.xlsx':
        df_ref = pd.read_excel(file_name, sheet_name = '1.1 Referral_Daily Input ', dtype = str)#, skiprows=1)
        df_partner = pd.read_excel(file_name, sheet_name = '1.2 Referral_Partner List',  dtype = str)
        df_chc = pd.read_excel(file_name, sheet_name = '2. CHC_Daily Input', dtype = str, skiprows=[1]) #Chỉnh 1911
        df_b2c = pd.read_excel(file_name, sheet_name = '3. Daily_B2C Input', dtype = str, skiprows=[1])
        if file_name == link + '2025_TMBD_Hospital_Daily Tracking.xlsx':
            df_partner.drop(columns = ['Mã đối tác.1'], inplace = True)
    elif file_name == link + 'Hospital_Daily Tracking_Template Region2 (Ver Apr 14).xlsx':
        df_ref = pd.read_excel(file_name, sheet_name = '1.1 Referral_Daily Input ', dtype = str)
        df_partner = pd.read_excel(file_name, sheet_name = '1.2 Referral_Partner List',  dtype = str)
        df_chc = pd.read_excel(file_name, sheet_name = '2. CHC_Daily Input', dtype = str, skiprows=[1])
        df_b2c = pd.read_excel(file_name, sheet_name = '3. Daily_B2C Input', dtype = str)
    else:
        df_ref = pd.read_excel(file_name, sheet_name = '1.1 Referral_Daily Input ', dtype = str)
        df_partner = pd.read_excel(file_name, sheet_name = '1.2 Referral_Partner List',  dtype = str)
        df_chc = pd.read_excel(file_name, sheet_name = '2. CHC_Daily Input', dtype = str)
        df_b2c = pd.read_excel(file_name, sheet_name = '3. Daily_B2C Input', dtype = str)
    if file_name == link + '2025_HMDL_Hospital_Daily Tracking_Template.xlsx':
        #df_b2c_2 = pd.read_excel(file_name, sheet_name = 'Digital sales - data', dtype = str)
        df_partner.drop(columns = ['Mã đối tác HIS'], inplace = True)
    for col in df_ref.columns:
        if df_ref[col].dtype != 'datetime64[ns]':# and df_ref[col].dtype != 'float64':
            df_ref[col] = df_ref[col].astype(str)
            df_ref[col] = df_ref[col].apply(remove_space)
            df_ref[col] = df_ref[col].str.upper()
            df_ref[col] = df_ref[col].replace('NAN','')
    for col in df_partner.columns:
        if df_partner[col].dtype != 'datetime64[ns]':# and df_partner[col].dtype != 'float64':
            df_partner[col] = df_partner[col].astype(str)
            df_partner[col] = df_partner[col].apply(remove_space)
            df_partner[col] = df_partner[col].str.upper()
            df_partner[col] = df_partner[col].replace('NAN','')
    for col in df_chc.columns:
        if df_chc[col].dtype != 'datetime64[ns]':# and df_chc[col].dtype != 'float64':
            df_chc[col] = df_chc[col].astype(str)
            df_chc[col] = df_chc[col].apply(remove_space)
            df_chc[col] = df_chc[col].str.upper()
            df_chc[col] = df_chc[col].replace('NAN','')
    for col in df_b2c.columns:
        if df_b2c[col].dtype != 'datetime64[ns]':# and df_b2c[col].dtype != 'float64':
            df_b2c[col] = df_b2c[col].astype(str)
            df_b2c[col] = df_b2c[col].apply(remove_space)
            df_b2c[col] = df_b2c[col].str.upper()
            df_b2c[col] = df_b2c[col].replace('NAN','')
    '''if file_name == link + '2025_HMDL_Hospital_Daily Tracking_Template.xlsx':
        for col in df_b2c_2.columns:
            if df_b2c_2[col].dtype != 'datetime64[ns]':
                df_b2c_2[col] = df_b2c_2[col].astype(str)
                df_b2c_2[col] = df_b2c_2[col].apply(remove_space)
                df_b2c_2[col] = df_b2c_2[col].str.upper()
                df_b2c_2[col] = df_b2c_2[col].replace('NAN','')
        df_b2c_2[df_b2c_2.columns[13]] = df_b2c_2[df_b2c_2.columns[13]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
        df_b2c_2[df_b2c_2.columns[15]] = df_b2c_2[df_b2c_2.columns[15]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
        df_b2c_2[df_b2c_2.columns[16]] = df_b2c_2[df_b2c_2.columns[16]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
        df_b2c_2[df_b2c_2.columns[17]] = df_b2c_2[df_b2c_2.columns[17]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
        df_b2c_2[df_b2c_2.columns[18]] = df_b2c_2[df_b2c_2.columns[18]].astype(str).apply(convert_datetime).astype('datetime64[ns]')'''
    
    if file_name == link + 'HMBP - Hospital_Daily Tracking_Template 10.04.25.xlsx':
        df_b2c_2 = pd.read_excel(file_name, sheet_name = '3. Daily_B2C - trade mkt', dtype = str, skiprows=[0])
        for col in df_b2c_2.columns:
            if df_b2c_2[col].dtype != 'datetime64[ns]':# and df_b2c_2[col].dtype != 'float64':
                df_b2c_2[col] = df_b2c_2[col].astype(str)
                df_b2c_2[col] = df_b2c_2[col].apply(remove_space)
                df_b2c_2[col] = df_b2c_2[col].str.upper()
                df_b2c_2[col] = df_b2c_2[col].replace('NAN','')
        df_b2c_2[df_b2c_2.columns[13]] = df_b2c_2[df_b2c_2.columns[13]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
        df_b2c_2[df_b2c_2.columns[15]] = df_b2c_2[df_b2c_2.columns[15]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
        df_b2c_2[df_b2c_2.columns[16]] = df_b2c_2[df_b2c_2.columns[16]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
        df_b2c_2[df_b2c_2.columns[17]] = df_b2c_2[df_b2c_2.columns[17]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
        df_b2c_2[df_b2c_2.columns[18]] = df_b2c_2[df_b2c_2.columns[18]].astype(str).apply(convert_datetime).astype('datetime64[ns]')

        #mask = df_b2c_2[df_b2c_2.columns[18]].dt.month != df_b2c_2['THÁNG KHÁM'].astype(int)
        #df_b2c_2.loc[mask, df_b2c_2.columns[18]] = pd.to_datetime(df_b2c_2.loc[mask, df_b2c_2.columns[18]].dt.strftime("%Y-%d-%m"), format="%Y-%m-%d", errors="coerce")


    if file_name == link + 'HMCL - Hospital_Daily Tracking_Template 10.04.25.xlsx':
        df_b2c_2 = pd.read_excel(file_name, sheet_name = '5. Digital Organic', dtype = str, skiprows=[0])
        for col in df_b2c_2.columns:
            if df_b2c_2[col].dtype != 'datetime64[ns]':# and df_b2c_2[col].dtype != 'float64':
                df_b2c_2[col] = df_b2c_2[col].astype(str)
                df_b2c_2[col] = df_b2c_2[col].apply(remove_space)
                df_b2c_2[col] = df_b2c_2[col].str.upper()
                df_b2c_2[col] = df_b2c_2[col].replace('NAN','')
        df_b2c_2[df_b2c_2.columns[13]] = df_b2c_2[df_b2c_2.columns[13]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
        df_b2c_2[df_b2c_2.columns[15]] = df_b2c_2[df_b2c_2.columns[15]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
        df_b2c_2[df_b2c_2.columns[16]] = df_b2c_2[df_b2c_2.columns[16]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
        df_b2c_2[df_b2c_2.columns[17]] = df_b2c_2[df_b2c_2.columns[17]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
        df_b2c_2[df_b2c_2.columns[18]] = df_b2c_2[df_b2c_2.columns[18]].astype(str).apply(convert_datetime).astype('datetime64[ns]')

        #df_b2c[df_b2c.columns[18]] = df_b2c[df_b2c.columns[18]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
        #mask = df_b2c[df_b2c.columns[18]].dt.month != df_b2c['Tháng ghi nhận'].astype(int)
        #df_b2c.loc[mask, df_b2c.columns[18]] = pd.to_datetime(df_b2c.loc[mask, df_b2c.columns[18]].dt.strftime("%Y-%d-%m"), format="%Y-%m-%d", errors="coerce")

        mask = df_b2c_2[df_b2c_2.columns[18]].dt.month != df_b2c_2['Tháng ghi nhận'].astype(int)
        df_b2c_2.loc[mask, df_b2c_2.columns[18]] = pd.to_datetime(df_b2c_2.loc[mask, df_b2c_2.columns[18]].dt.strftime("%Y-%d-%m"), format="%Y-%m-%d", errors="coerce")

    
    #df_ref[df_ref.columns[2]]= df_ref[df_ref.columns[2]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_ref[df_ref.columns[12]] = df_ref[df_ref.columns[12]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_ref[df_ref.columns[13]] = df_ref[df_ref.columns[13]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_ref[df_ref.columns[14]] = df_ref[df_ref.columns[14]].astype(str).apply(convert_datetime).astype('datetime64[ns]')

    '''Thêm vào cho region 3'''
    #mask = df_ref[df_ref.columns[14]].dt.month != df_ref['Tháng ghi nhận'].astype(int)
    #df_ref.loc[mask, df_ref.columns[14]] = pd.to_datetime(df_ref.loc[mask, df_ref.columns[14]].dt.strftime("%Y-%d-%m"), format="%Y-%m-%d", errors="coerce")


    #df_partner[df_partner.columns[1]] = df_partner[df_partner.columns[1]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_partner[df_partner.columns[9]] = df_partner[df_partner.columns[9]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_chc[df_chc.columns[9]] = df_chc[df_chc.columns[9]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_chc[df_chc.columns[14]] = df_chc[df_chc.columns[14]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_chc[df_chc.columns[20]] = df_chc[df_chc.columns[20]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_chc[df_chc.columns[23]]  = df_chc[df_chc.columns[23]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_b2c[df_b2c.columns[13]] = df_b2c[df_b2c.columns[13]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_b2c[df_b2c.columns[15]] = df_b2c[df_b2c.columns[15]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_b2c[df_b2c.columns[16]] = df_b2c[df_b2c.columns[16]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_b2c[df_b2c.columns[17]] = df_b2c[df_b2c.columns[17]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_b2c[df_b2c.columns[18]] = df_b2c[df_b2c.columns[18]].astype(str).apply(convert_datetime).astype('datetime64[ns]')

    '''HMDNG'''
    #mask = df_b2c[df_b2c.columns[18]].dt.month != df_b2c['Tháng'].astype(int)
    #df_b2c.loc[mask, df_b2c.columns[18]] = pd.to_datetime(df_b2c.loc[mask, df_b2c.columns[18]].dt.strftime("%Y-%d-%m"), format="%Y-%m-%d", errors="coerce")

    '''Thêm vào cho region 3'''
    if file_name == link + 'HMCL - Hospital_Daily Tracking_Template 10.04.25.xlsx':
        mask = df_ref[df_ref.columns[14]].dt.month != df_ref['Tháng ghi nhận'].astype(int)
        df_ref.loc[mask, df_ref.columns[14]] = pd.to_datetime(df_ref.loc[mask, df_ref.columns[14]].dt.strftime("%Y-%d-%m"), format="%Y-%m-%d", errors="coerce")
        
        mask = df_b2c[df_b2c.columns[18]].dt.month != df_b2c['Tháng ghi nhận'].astype(int)
        df_b2c.loc[mask, df_b2c.columns[18]] = pd.to_datetime(df_b2c.loc[mask, df_b2c.columns[18]].dt.strftime("%Y-%d-%m"), format="%Y-%m-%d", errors="coerce")

    if file_name == link + 'HMMH - Hospital_Daily Tracking_Template 10.04.25.xlsx':
        #print(df_b2c['Tháng ghi nhận'])
        mask = df_b2c[df_b2c.columns[18]].dt.month != df_b2c['Tháng ghi nhận theo tài chính đã EDIT cut of time 30day  tại HMMH (Tuyền BC)'].astype(int)
        df_b2c.loc[mask, df_b2c.columns[18]] = pd.to_datetime(df_b2c.loc[mask, df_b2c.columns[18]].dt.strftime("%Y-%d-%m"), format="%Y-%m-%d", errors="coerce")
    
    """df_b2c_2[df_b2c_2.columns[13]] = df_b2c_2[df_b2c_2.columns[13]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_b2c_2[df_b2c_2.columns[15]] = df_b2c_2[df_b2c_2.columns[15]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_b2c_2[df_b2c_2.columns[16]] = df_b2c_2[df_b2c_2.columns[16]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_b2c_2[df_b2c_2.columns[17]] = df_b2c_2[df_b2c_2.columns[17]].astype(str).apply(convert_datetime).astype('datetime64[ns]')
    df_b2c_2[df_b2c_2.columns[18]] = df_b2c_2[df_b2c_2.columns[18]].astype(str).apply(convert_datetime).astype('datetime64[ns]')"""

    '''Xử lý số có dấu .'''
    df_chc[df_chc.columns[16]] = df_chc[df_chc.columns[16]].apply(remove_dot_between_digits)#.astype('float')
    df_chc[df_chc.columns[18]] = df_chc[df_chc.columns[18]].apply(remove_dot_between_digits)#.astype('float')

    if file_name == link + '2025_HMDL_Hospital_Daily Tracking_Template.xlsx': ##Thêm vào 2611
        df_chc.insert(29, "Discount", df_chc['Mức giảm giá'])
        df_chc.insert(30, "Broker fee", df_chc['Mức hoa Hồng /HĐ'])
        df_chc.insert(31, "EBITDA", "")
    if file_name == link + '2025_TMBD_Hospital_Daily Tracking.xlsx':
        df_chc.insert(29, "Discount", "")
        df_chc.insert(30, "Broker fee", "")
        df_chc.insert(31, "EBITDA", "")
    if file_name == link + 'HMGPXL_Daily Tracking.xlsx':
        df_chc.insert(29, "Discount", "")
        df_chc.insert(30, "Broker fee", "")
        df_chc.insert(31, "EBITDA", "")
    if file_name == link + '2025_HMDNG_Hospital_Daily Tracking.xlsx':
        df_ref[df_ref.columns[7]] = df_ref[df_ref.columns[7]].apply(HMDNG_ref_daily)
        df_partner[df_partner.columns[5]] = df_partner[df_partner.columns[5]].apply(HMDNG_ref_partner)
        df_chc.insert(29, "Discount", "")
        df_chc.insert(30, "Broker fee", "")
        df_chc.insert(31, "EBITDA", "")
    if file_name == link + 'Hospital_Daily Tracking_Template Region2 (Ver Apr 14).xlsx':
        df_ref[df_ref.columns[7]] = df_ref[df_ref.columns[7]].apply(ITO_ref_daily)
        df_partner[df_partner.columns[5]] = df_partner[df_partner.columns[5]].apply(ITO_ref_partner)
        df_chc.insert(29, "Discount", "")
        df_chc.insert(30, "Broker fee", "")
        df_chc.insert(31, "EBITDA", "")
    if file_name == link + 'HMMH - Hospital_Daily Tracking_Template 10.04.25.xlsx':
        df_ref[df_ref.columns[7]] = df_ref[df_ref.columns[7]].apply(HMMH_ref_daily)
    if file_name == link + 'HMBD - Hospital_Daily Tracking_Template 10.04.25.xlsx':
        df_ref[df_ref.columns[7]] = df_ref[df_ref.columns[7]].apply(HMBD_ref_daily)
        df_partner[df_partner.columns[5]] = df_partner[df_partner.columns[5]].apply(HMBD_ref_partner)
    if file_name == link + 'HMDNI - Hospital_Daily Tracking_Template 10.04.25.xlsx':
        df_ref[df_ref.columns[7]] = df_ref[df_ref.columns[7]].apply(HMDNI_ref_daily)
        df_partner[df_partner.columns[5]] = df_partner[df_partner.columns[5]].apply(HMDNI_ref_partner)
    if file_name == link + 'HMBP - Hospital_Daily Tracking_Template 10.04.25.xlsx':
        df_ref[df_ref.columns[7]] = df_ref[df_ref.columns[7]].apply(HMBP_ref_daily)
    if file_name == link + 'HMCL - Hospital_Daily Tracking_Template 10.04.25.xlsx':
        df_ref[df_ref.columns[7]] = df_ref[df_ref.columns[7]].apply(HMCL_ref_daily)
    if file_name == link + 'Hospital_Daily Tracking.xlsx':
        df_ref[df_ref.columns[7]] = df_ref[df_ref.columns[7]].apply(HPH_ref_daily)
        df_chc.insert(29, "Discount", "")
        df_chc.insert(30, "Broker fee", "")
        df_chc.insert(31, "EBITDA", "")
    if file_name == link + 'Giáp_Hospital tracking TMTDM.xlsx':
        df_partner[df_partner.columns[5]] = df_partner[df_partner.columns[5]].apply(TMTDM_ref_partner)
        df_chc.insert(29, "Discount", df_chc['Mức giảm giá'])
        df_chc.insert(30, "Broker fee", df_chc['Mức hoa Hồng /HĐ'])
        df_chc.insert(31, "EBITDA", "")
    if file_name == link + 'HMTD_Daily Tracking_New link.xlsx':
        df_ref[df_ref.columns[7]] = df_ref[df_ref.columns[7]].apply(HMTD_ref_daily)
        df_partner[df_partner.columns[5]] = df_partner[df_partner.columns[5]].apply(HMTD_ref_partner)
        df_chc.insert(29, "Discount.1", df_chc['Discount'])
        df_chc.insert(30, "Broker fee.1", df_chc['Customer commission'])
        df_chc.insert(31, "EBITDA.1", df_chc['Ebitda'])
    if file_name == link + '2025 hmsg daily tracking sales.xlsx':
        df_ref[df_ref.columns[7]] = df_ref[df_ref.columns[7]].apply(HMSG_ref_daily)
        df_partner[df_partner.columns[5]] = df_partner[df_partner.columns[5]].apply(HMSG_ref_partner)
    if file_name == link + 'HMV_2025 Hospital_Daily Tracking - Copy 11.06.2025.xlsx':
        df_ref[df_ref.columns[7]] = df_ref[df_ref.columns[7]].apply(HMV_ref_daily)
        df_partner[df_partner.columns[5]] = df_partner[df_partner.columns[5]].apply(HMV_ref_partner)
        df_chc.insert(29, "Discount", "")
        df_chc.insert(30, "Broker fee", "")
        df_chc.insert(31, "EBITDA", "")

    df_map = pd.read_excel('C:/Users/lpn001-ho/OneDrive - Hoan My Medical Corporation/Daily Tracking/Map chuyên khoa.xlsx')
    map_dict = dict(zip(df_map['specialty'], df_map['Tên chuyên khoa để Map']))
    df_ref[df_ref.columns[16]] = df_ref[df_ref.columns[16]].map(map_dict)
    df_b2c[df_b2c.columns[10]] = df_b2c[df_b2c.columns[10]].map(map_dict)
    with pd.ExcelWriter(output, engine='xlsxwriter') as writer:
        df_ref.to_excel(writer, sheet_name='1.1 Referral_Daily Input ', index=False)
        df_partner.to_excel(writer, sheet_name='1.2 Referral_Partner List', index=False)
        df_chc.to_excel(writer, sheet_name='2. CHC_Daily Input', index=False)
        df_b2c.to_excel(writer, sheet_name='3. Daily_B2C Input', index=False)
        #if file_name == link + '2025_HMDL_Hospital_Daily Tracking_Template.xlsx':
        #    df_b2c_2.to_excel(writer, sheet_name='Digital sales - data', index=False)
        if file_name == link + 'HMBP - Hospital_Daily Tracking_Template 10.04.25.xlsx':
            df_b2c_2[df_b2c_2.columns[10]] = df_b2c_2[df_b2c_2.columns[10]].map(map_dict)
            df_b2c_2.to_excel(writer, sheet_name='3. Daily_B2C - trade mkt', index=False)
        if file_name == link + 'HMCL - Hospital_Daily Tracking_Template 10.04.25.xlsx':
            df_b2c_2[df_b2c_2.columns[10]] = df_b2c_2[df_b2c_2.columns[10]].map(map_dict)
            df_b2c_2.to_excel(writer, sheet_name='5. Digital Organic', index=False)

# %%
for item1, item2 in zip(input_list, output_list):
    file_name = link + item1
    print(file_name)
    output = 'C:/Users/lpn001-ho/OneDrive - Hoan My Medical Corporation/Daily Tracking/' + item2
    print(output)
    processing(file_name, output)
# Out:
# C:/Users/lpn001-ho/OneDrive - Hoan My Medical Corporation/Daily Tracking/100126/HMBP - Hospital_Daily Tracking_Template 10.04.25.xlsx
# C:/Users/lpn001-ho/OneDrive - Hoan My Medical Corporation/Daily Tracking/HMBP - Hospital_Daily Tracking_Template 10.04.25_python.xlsx
# c:\Users\lpn001-ho\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)
# c:\Users\lpn001-ho\AppData\Local\Programs\Python\Python310\lib\site-packages\openpyxl\worksheet\_reader.py:329: UserWarning: Data Validation extension is not supported and will be removed
#   warn(msg)

# %%
output_link = 'C:/Users/lpn001-ho/OneDrive - Hoan My Medical Corporation/Daily Tracking/'
def specialty(file_name):
    df_ref = pd.read_excel(file_name, sheet_name = '1.1 Referral_Daily Input ')
    df_b2c = pd.read_excel(file_name, sheet_name='3. Daily_B2C Input')
    df_map = pd.read_excel('C:/Users/lpn001-ho/OneDrive - Hoan My Medical Corporation/Daily Tracking/Map chuyên khoa.xlsx')
    map_dict = dict(zip(df_map['specialty'], df_map['Tên chuyên khoa để Map']))
    df_ref['Specialty/ Chuyên khoa'] = df_ref['Specialty/ Chuyên khoa'].map(map_dict)[:10]
    df_b2c['Specialty/ Chuyên khoa'] = df_b2c['Specialty/ Chuyên khoa'].map(map_dict)[:10]
    
    df_partner = pd.read_excel(file_name, sheet_name = '1.2 Referral_Partner List')
    df_chc = pd.read_excel(file_name, sheet_name = '2. CHC_Daily Input')
    with pd.ExcelWriter(output, engine='xlsxwriter') as writer:
        df_ref.to_excel(writer, sheet_name='1.1 Referral_Daily Input ', index=False)
        df_partner.to_excel(writer, sheet_name='1.2 Referral_Partner List', index=False)
        df_chc.to_excel(writer, sheet_name='2. CHC_Daily Input', index=False)
        df_b2c.to_excel(writer, sheet_name='3. Daily_B2C Input', index=False)
        #if file_name == link + '2025_HMDL_Hospital_Daily Tracking_Template.xlsx':
        #    df_b2c_2.to_excel(writer, sheet_name='Digital sales - data', index=False)
        if file_name == link + 'HMBP - Hospital_Daily Tracking_Template 10.04.25.xlsx':
            df_b2c_2.to_excel(writer, sheet_name='3. Daily_B2C - trade mkt', index=False)
        if file_name == link + 'HMCL - Hospital_Daily Tracking_Template 10.04.25.xlsx':
            df_b2c_2.to_excel(writer, sheet_name='5. Digital Organic', index=False)
